# %%
import sys
sys.path.append("..")
from src.hooked_model import HookedSparseGPT
import torch

# %%
model = HookedSparseGPT.from_pretrained("jacobcd52/ss_d128_f1", dtype=torch.bfloat16)

# %%
model.blocks[0].mlp.W_in.dtype
# Out:
# torch.bfloat16
